# %% [markdown]
# 수집시간 너무 오래걸려 한번에 돌리기! 24hrs

# %% [markdown]
# # 네이버 cafe 2020 contents 크롤링 _함수이용_ all day 실행편
# 제목/ 닉네임/ 날짜 / 내용/ 댓글 데이터 여러 페이지 한번에 가져오기

# %% [markdown]
# ## 01. 환경설정 및 함수 정의

# %%
import requests
import pandas as pd
import numpy as np 

import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import urllib.request
from bs4 import BeautifulSoup

# %% [markdown]
# ## 02. 데이터 수집 및 저장

# %%
# 스크롤 횟수 지정 len 확인하기
dal =8
if dal == 8:
    url = 'https://search.naver.com/search.naver?where=article&query=%EC%8C%80%20-%EC%97%85%EC%B2%B4%2C%20-%EC%A0%9C%EA%B3%B5%EB%B0%9B%2C%20-%EC%A7%80%EC%9B%90%EB%B0%9B%2C%20-%EC%9B%90%EA%B3%A0%EB%A3%8C%2C%20-%EB%AC%B4%EC%83%81%2C%20-%ED%98%91%EC%B0%AC%2C%20-%EC%86%8C%EC%A0%95%EC%9D%98%2C%20-%EC%82%AC%EB%A3%8C%2C%20-%EA%B3%A0%EB%9E%98%EB%B0%A5%2C%20-%EA%B8%B8%EB%83%A5%EC%9D%B4%2C%20-%EA%B3%A0%EC%96%91%EC%9D%B4%2C%20-%EA%B0%95%EC%95%84%EC%A7%80&ie=utf8&st=rel&date_option=99&date_from=2020.08.01&date_to=2020.08.31&board=&srchby=text&dup_remove=1&cafe_url=&without_cafe_url=&sm=tab_opt&nso=so%3Ar%2Cp%3Afrom20200801to20200831&nso_open=1&t=0&mson=0&prdtype=0'
if dal == 9:    
    url = 'https://search.naver.com/search.naver?where=article&query=%EC%8C%80%20-%EC%97%85%EC%B2%B4%2C%20-%EC%A0%9C%EA%B3%B5%EB%B0%9B%2C%20-%EC%A7%80%EC%9B%90%EB%B0%9B%2C%20-%EC%9B%90%EA%B3%A0%EB%A3%8C%2C%20-%EB%AC%B4%EC%83%81%2C%20-%ED%98%91%EC%B0%AC%2C%20-%EC%86%8C%EC%A0%95%EC%9D%98%2C%20-%EC%82%AC%EB%A3%8C%2C%20-%EA%B3%A0%EB%9E%98%EB%B0%A5%2C%20-%EA%B8%B8%EB%83%A5%EC%9D%B4%2C%20-%EA%B3%A0%EC%96%91%EC%9D%B4%2C%20-%EA%B0%95%EC%95%84%EC%A7%80&ie=utf8&st=rel&date_option=99&date_from=2020.09.01&date_to=2020.09.30&board=&srchby=text&dup_remove=1&cafe_url=&without_cafe_url=&sm=tab_opt&nso=so%3Add%2Cp%3Afrom20200901to20200930&nso_open=1&t=0&mson=0&prdtype=0'

browser = webdriver.Chrome("./chromedriver")
browser.get(url)
time.sleep(1)


#스크롤을 끝까지 내려주는 코드
while True:
    for w in range(2000):
        browser.find_element_by_css_selector("html").send_keys(Keys.END)
    break

title = browser.find_elements_by_css_selector("a.api_txt_lines.total_tit")

len(title)  #1000정도 수집할것. 따라서 다음 코드에서 range 2000으로 설정!
# Out:
# 1000

# %% [markdown]
# ## 수집 시작

# %%
# cafe
for dal in range(8,10):  # 8월부터 9월까지

    # 01. 페이지 준비(8월~ 9월 설정)
    if dal == 8:
        url = 'https://search.naver.com/search.naver?where=article&query=%EC%8C%80%20-%EC%97%85%EC%B2%B4%2C%20-%EC%A0%9C%EA%B3%B5%EB%B0%9B%2C%20-%EC%A7%80%EC%9B%90%EB%B0%9B%2C%20-%EC%9B%90%EA%B3%A0%EB%A3%8C%2C%20-%EB%AC%B4%EC%83%81%2C%20-%ED%98%91%EC%B0%AC%2C%20-%EC%86%8C%EC%A0%95%EC%9D%98%2C%20-%EC%82%AC%EB%A3%8C%2C%20-%EA%B3%A0%EB%9E%98%EB%B0%A5%2C%20-%EA%B8%B8%EB%83%A5%EC%9D%B4%2C%20-%EA%B3%A0%EC%96%91%EC%9D%B4%2C%20-%EA%B0%95%EC%95%84%EC%A7%80&ie=utf8&st=rel&date_option=99&date_from=2020.08.01&date_to=2020.08.31&board=&srchby=text&dup_remove=1&cafe_url=&without_cafe_url=&sm=tab_opt&nso=so%3Ar%2Cp%3Afrom20200801to20200831&nso_open=1&t=0&mson=0&prdtype=0'
    if dal == 9:    
        url = 'https://search.naver.com/search.naver?where=article&query=%EC%8C%80%20-%EC%97%85%EC%B2%B4%2C%20-%EC%A0%9C%EA%B3%B5%EB%B0%9B%2C%20-%EC%A7%80%EC%9B%90%EB%B0%9B%2C%20-%EC%9B%90%EA%B3%A0%EB%A3%8C%2C%20-%EB%AC%B4%EC%83%81%2C%20-%ED%98%91%EC%B0%AC%2C%20-%EC%86%8C%EC%A0%95%EC%9D%98%2C%20-%EC%82%AC%EB%A3%8C%2C%20-%EA%B3%A0%EB%9E%98%EB%B0%A5%2C%20-%EA%B8%B8%EB%83%A5%EC%9D%B4%2C%20-%EA%B3%A0%EC%96%91%EC%9D%B4%2C%20-%EA%B0%95%EC%95%84%EC%A7%80&ie=utf8&st=rel&date_option=99&date_from=2020.09.01&date_to=2020.09.30&board=&srchby=text&dup_remove=1&cafe_url=&without_cafe_url=&sm=tab_opt&nso=so%3Add%2Cp%3Afrom20200901to20200930&nso_open=1&t=0&mson=0&prdtype=0'
    
    browser = webdriver.Chrome("./chromedriver")
    browser.get(url)
    time.sleep(1)


    #스크롤을 끝까지 내려주는 코드
    while True:
        for w in range(2000):
            browser.find_element_by_css_selector("html").send_keys(Keys.END)
        break


    # 최종 저장 리스트
    #제목 / 날짜
    titles = []
    dates = []
    #내용
    contents = []
    #id
    ids = []
    #댓글
    chats = []
    chats2 = []


    title = browser.find_elements_by_css_selector("a.api_txt_lines.total_tit")
    date = browser.find_elements_by_css_selector("span.sub_time.sub_txt")

    cnt = 0
    while cnt <= 1050 :
        try:

            titles.append(title[cnt].text)
            dates.append(date[cnt].text)

            title[cnt].click()

            time.sleep(4)

            browser.switch_to.window(browser.window_handles[-1])

            try:

                browser.switch_to.frame('cafe_main')
                #content
                try:
                    blogcontent = browser.find_elements_by_css_selector(
                        "div.ContentRenderer")
                    for i in blogcontent:
                        contents.append(i.text)
                    if blogcontent == []:
                        blogcontent = browser.find_elements_by_css_selector(
                            "div.se-main-container")
                        for i in blogcontent:
                            contents.append(i.text)
                    if blogcontent == []:
                        contents.append(np.nan)  
                except:
                    contents.append(np.nan)

                
                #id
                try:        
                    ids.append(browser.find_element_by_css_selector("a.nickname").text)
                except:
                    ids.append(np.nan)


                #chat

                try:
                    blogchat = browser.find_elements_by_css_selector(
                        "span.text_comment")
                    midchat=[]
                    q = ""

                    for j in blogchat:
                        q += j.text +  " || "
                        midchat.append(j.text)
                    chats.append(q)
                    chats2.append(midchat)
                except:
                    chats.append(np.nan)
                    chats2.append(np.nan)
                
                browser.close()
                browser.switch_to.window(browser.window_handles[0])
            
            except:
                
                browser.close()
                browser.switch_to.window(browser.window_handles[0])

                chats.append(np.nan)
                contents.append(np.nan)
                ids.append(np.nan)
        
        except:
            browser.switch_to.window(browser.window_handles[-1])

        cnt += 1
        


    #저장
    a=pd.DataFrame(titles,columns=["title"])
    b = pd.DataFrame(dates, columns=["date"])
    c = pd.DataFrame(chats, columns=["chat"])
    d = pd.DataFrame(contents, columns=["content"])
    e = pd.DataFrame(ids,columns=["id"])

    df = pd.concat([a, b, c, d, e], axis=1)
    
    #05.엑셀파일로 저장
    df.to_excel(f'./recrawlblog/naver_cafe_conents_ssal_2020_{dal}월.xlsx')

    ##06. 드라이버 종료
    browser.close()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:935: UserWarning: Ignoring URL 'https://m.blog.naver.com/danybebe/222050663570
#
# https://m.cafe.naver.com/minsermooing/685917
#
# 네이버) danybebe
# 인스타) cdi_08
# 스토어찜, 소식받기 완료
#
# 홍국쌀 + 클로렐라쌀 희망합니다
#
# 건강도 챙기고 시각, 미각 모두 챙길수있는
# 컬러쌀이네요.
# 제품이미지 사진과 밥지었을때 이미지,
# 아이가 먹는모습 사진까지 담아볼게요 ||  ||  || 응모완료 || https://m.blog.naver.com/ahyunah/222050667325
#
# https://www.facebook.com/100040670251048/posts/320479039317769/
#
# 요즘 색깔놀이에 흠뻑
# 빠진 첫째와 예쁜 색 밥을 지어
# 행복한 식사시간을 보내고 싶네요ㅎㅎ
#
# 정성후기 약속합니다🤗 || 응모완료 || 영양쌀 기능성쌀 너무 좋네요
#
# ▶ 개인블로그 url
# https://blog.naver.com/songekim/222051061554
#
# 타카페 스크랩 url
# https://cafe.naver.com/happymmm/1194290
# https://cafe.naver.com/happymmm/1194289
#
# ▶ 네이버아이디 : songekim
#
# ▶ 인스타주소 : https://www.instagram.com/songekim00
#
# ▶ 체험하고싶은 이유/후기작성 계획
#
# 하나로라이스 컬러쌀
# 진심 대박인거 같아여
# 하나로라이스 컬러쌀은
# 백미에 혼합하여
# 해서 먹으면 너무 좋을것
# 같아요 ! 무엇보다
# 여주쌀 진상미 특품종으로
# 만들어져서 밥이 찰지다고
# 하는데요 최고인거 같아요
# 그래서 간절히 꼭!! 체험해보고
# 싶은 마음 이예요
# 그래서 응모하게 되엇습니다
# 제가 만약에 체험할수 잇다면
# 진심 정성스러운 후기 반드시
# 약속 하겠습니다
#
# 스토어팜소식받기/찜 완료 || 응모완료 || 응원해요 ||  || https://m.cafe.naver.com/15668981/4129471
# https://m.blog.naver.com/ckjgeddms/222050676525
#
# 네이버: ckjgeddms
# 인스타: taeyang0616
#
# 컬러 영양쌀이라니!!♡.♡ 보기에도 좋고 맛도 좋을것같아 저희집 아가도 해먹이고 가족과 함께 건강하고 맛있는 식사 할 수 있겠어요~아기에게 예쁘게 주먹밥 해먹이고 싶어요^^ || 응모완료 ||  ||  ||  || https://jinyi77.blog.me/222050679541
# https://cafe.naver.com/foodballmanager/821724
# https://cafe.naver.com/enuriprosumer/87358
# https://cafe.naver.com/15668981/4129475
#
# 네이버아이디 : jinyi77
# 인스타아이디 : @ilovejjins
#
# 스토어찜완료 / 소식받기완료
#
# 아이가 성장기라서 기능성쌀을 엄청 알아보고 있던중이예요~ 최근에 하이아미쌀을 먹이기 시작했어요~ 매일먹은 쌀만으로 아이의 영양을 챙길수 있어서 너무 좋더라구요~하나로 라이스는 이외에 특히 챙기고 싶은 부분을 신경쓸수 있어서 정말~ 아이에게 먹이고 싶어요~ 눈이 너무 않좋아서 ㅠㅠ 루테인쌀과 클로렐라쌀도 먹여보고 싶구요~ 고루고루 챙겨보고 싶어요~ 성장기의 아이라 한창 클 요즘~ 한국인의 밥상의 힘만으로도 영양을 가득 채울수 있는 하나로 라이스로 밥상차리고 싶어요~ || "응모완료" || 너무맛있어보여용!^^ || https://m.blog.naver.com/sujissi/222050720370
# https://cafe.naver.com/happymmm/1194251
#
# 네이버ID: sujissi
#
# 보기만해도 건강해질것 같은 영양쌀이네요~^^
# 맛도 너무 궁금하고 기대되요 꼭 먹어보고 싶어요~
# 색깔이 있어서 예쁘게 모양내서 만들어주면 아이가 정말 좋아할것 같아요 갓지은 밥부터 영양밥, 주먹밥 등 다양하게 조리한 모습 예쁜 플레이팅과 정성스런 후기 남기겠습니다 예쁘고 정성스런 후기 약속드려요~ || 응모완료 ||  || https://m.blog.naver.com/cgh624/222050749605
#
# https://story.kakao.com/_hCsYq9/fX7eG1XKCs0
#
# 네이버 cgh624
# 인스타 thekznzl03
#
# 홍국쌀 클로렐라 신청합니다
# 신기하기도하고 영양에도좋을거같아서 꾸준히 먹어보고싶어요 맛있고 건강한쌀 농협브랜드믿고 먹고싶어요 신청합니다~~♡ ||  || 응모완료 || https://m.blog.naver.com/skyttpsk/222050748674
#
#
# https://story.kakao.com/skyttpsk/jS443yskcTA
#
# 네이버 skyttpsk
# 인스타 skyekscn
#
# 루테인쌀 클로렐라쌀 신청해요♡ 보자마자 요걸로주먹밥만들면 얼마나이쁠까라는생각이들더라구요~! 아가가커가면서 자꾸티비보러 앞으로앞으로가는데 밥먹으면서 루테인도챙기고 색깔도이쁜게 너무메리트네요♡ || 응모완료 || https://blog.naver.com/kaki7790/222050762024
# https://m.facebook.com/story.php?story_fbid=3057869990935156&id=100001365552677
# 네이버아이디 : kaki7790
#
# 영양가득 컬러쌀이네요.
# 아이랑 눈으로 보고 맛으로 먹고, 다채롭게 오감놀이 할수 있을것 같아요.
# 백미쌀 씻어서 바로 넣을수 있으니 간편하고, 맛있게 밥지어서 주먹밥에 비빔밥에 디양하게 해먹는 모습 올리겠습니다.
#
# 가족과 함께 하는 모습 올릴께요 || 응모완료 || https://m.blog.naver.com/manggo35/222050767005
#
# https://cafe.naver.com/happymmm/1194256
# 네이버 manggo35
#
#
# 컬러가 있어서 밥 먹게 싫어하는 아이에게 먹이기 너무 좋을 것 같아요 ^^ || 응모완료 || https://m.blog.naver.com/seongderella/222050772418
# https://m.cafe.naver.com/1momsheart/701816
#
# 네이버 : seongderella
# 인스타 : seongderella
#
# 선택 : 강황쌀+버섯쌀
#
# 어머, 이렇게 다양한 색의 쌀이 있을줄이야...
# 종종 김밥 만들때 색깔있는 밥을 넣고는 싶은데, 귀찮아서 못했거든요. 하나로라이스 컬러쌀만 있으면, 간단하게 예쁜 밥짓기를 할 수 있어서 너무 좋을 것 같아요.
# 저희 남편이 도시락을 싸다녀서 김밥이나 무스비, 삼각김밥 등을 종종 싸주는데요, 컬러쌀로 만들면 정말 인기만점이겠죠?
#
# 색도 예쁜데 영양도 듬뿍! 거기에 여주 진상미를 사용했다고 하니 맛과 품질까지 보장되네요. 이건 꼭 먹어보고 주변에 소문내야겠어요~~
# 하나로라이스로 우리집 밥상을 화려하게 꾸며보고 싶어요^^ ||  || 응모완료 || https://m.blog.naver.com/PostView.nhn?blogId=paple21&logNo=222050801560
#
#
# https://cafe.naver.com/shezliving/450192
#
# 네이버 아이디 paple21
#
# 루테인쌀 + 클로렐라쌀
#
# 눈건강을 위한 루테인쌀과 엽록소 팍팍~ 클로렐라쌀
# 요즘 야근에 지친 남편을 위해 영양소 듬뿍 들어간 보기도 좋고 양양가 넘치는 예쁘고 건강한 밥상 선물해주고 싶어요 || 응모완료 || https://m.blog.naver.com/lky613/222050800273
# https://cafe.naver.com/15668981/4129558
#
# 네이버아이디 lky613
#
# 이렇게 이쁜 컬러쌀이라면 집나갔던 밥맛도 돌아올거 같애요 ㅎ 아가한테도 이쁘게 밥해서 챙겨주고 싶네요 ㅎ 눈으로도 먹는다는 말이 있져 예쁜 밥상 후기도 올릴게요 ^^ || 스토어찜 완료
# 응모완료 || https://story.kakao.com/_CDFtd4/kDFtyz1mcTA
#
# https://m.blog.naver.com/rhrtkfkdgkse/222050801591
#
# 네이버 rhrtkfkdgkse
#
# 색깔도 이쁘고 몸에도 좋은 쌀이라니 너무 좋네요!아기 이유식과 간식에 이쁘게 꾸며서 주고싶어요!
# 사진,동영상 꼼꼼하게 후기잘쓸자신있어요 || 응모완료 || https://blog.naver.com/mira2224/222050800407
# https://cafe.naver.com/wedse/12288
#
# 네이버 mira2224
# 선택 : 강황쌀&버섯쌀
#
# 개구쟁이 아이를 키우고 있는 육아맘입니다! 아이가 밥을 잘 먹지 않으려고하는데요~
# 요렇게 예쁜 색의 밥을 만들어주면 너무 좋아할 것 같아요!^^
# 아이와 함께 여러 색의 밥으로 주먹밥도 만들고, 김밥도 만들어 보고 싶어요~~~^^ || 응모완료 ||  || https://hbhee91.blog.me/222050886369
# https://cafe.naver.com/15668981/4129603
#
# 네이버) hbhee91
# 인스타) hb.hee
# 스토어찜, 소식받기 완료
#
# 강황쌀 + 클로렐라쌀 희망해요~
# 곧 아이랑 함께 나들이 갈껀데 김밥으로 만들면 너무 이쁠것 같아요!
# 그리고 이유식 간식으로도 예쁘게 만들수 있을것 같아서 너무 기대됩니다! ||  || 응모완료 || https://blog.naver.com/anmi02/222050939260
# https://www.instagram.com/anhyoju679
# 네이버 anmi02
# 인스타 anhyoju679
#
# 루테인쌀 + 클로렐라쌀 신청합니다
#
# 보기좋은 떡이 먹기도 좋다고 건강에도 좋고
# 주먹밥같은거 만들때 좋을꺼같아요
#
# 응모완료 || https://cafe.naver.com/bornnborn/1334067
# https://blog.naver.com/protoss93/222050723644
#
# 네이버, 인스타 protoss93
#
# 홍국쌀+클로렐라쌀
#
# 친정아빠가 암투병 하시게 되면서 저도 건강에 부쩍 신경쓰게되었는데
# 일바쁜 신랑이나 공부하느라 힘든 딸아이를 위해서라도
# 몸에좋은 기능성쌀로 입맛도 살리고
# 무더운여름건강하게 나면 좋겠네요
# 꼼꼼하게 후기 작성하겠습니다 ||  || 응모완료 || https://cafe.naver.com/happymmm/1194318
# https://blog.naver.com/pleehe/222051291428
#
# 네이버 pleehe
# 인스타 jjong2a
#
# 와 ~ 이때까지 흰쌀밥만 먹어왔는데 말이죠 !!
# 저에게는 약간 충격?으로 다가왔네요 ㅎㅎ
# 요즘 색에 관심이 많은 아이에게
# 재미있고 건강한 쌀을 알려주고 싶어요!!
#
#
# 꼼꼼하고 맛있는 후기 남기겠습니다. ||  || 응모완료 || https://m.blog.naver.com/kjes22/222051444471
# https://cafe.naver.com/1momsheart/701872
#
# 네이버 kjes22
# 인스타gimjieun544
#
# 쌀에 색깔이있고 몸에좋은 쌀이라니
# 아직 호기심많은 아이에게특별한 밥으로 건강하고
# 맛있는 식사시간을
# 만들어주고싶어요
# 넘나신기하네요~^^ ||  || 응모완료 || https://m.blog.naver.com/jmax0311/222051454037
#
# https://cafe.naver.com/imamang/256582
# 강황쌀+클로렐라쌀
#
# 네이버 jmax0311
#
# 우리 아가 유아식으로 좋을꺼 같아 신청합니다
# 예쁘게 맛깔나게 만들어볼께요 || https://blog.naver.com/tjheh/222051656905
# https://cafe.naver.com/happyreview/908724
#
# 아이디 tjheh
# 인스타 tjheh
#
# 홍국쌀, 버섯쌀
#
# 색상도 이쁜데 영양까지 좋은 쌀이어서 아가 밥할때 해주면 색때문에 아기가 넘넘 맛나게 잘 먹을꺼같아요
# 언능 체험단 신청합니다~ 후기는 정성껏 남길께여~ ||  || 응모완료 || https://m.blog.naver.com/tjssu4372/222051664741
# https://m.cafe.naver.com/vblog/85578
# https://m.cafe.naver.com/happymmm/1194353
#
# 네이버:tjssu4372
# 인스타:seon_son
#
# 홍국쌀,버섯쌀
#
#
#
# 아이디어가 너무 좋아요.보는 즐거움 건강까지 생각한 컬러쌀
# 선택하는데 너무 고민이 많이 되었어요.
#
# 너무 예쁜 컬러쌀을 사용해서 아이들과 예쁜 김밥 만들고 싶어요.
# 체험활동 영상포함해서 꼼꼼하게 작성하겠습니다. ||  || 응모완료 || ▶ https://cafe.naver.com/imompapa/158013
# https://blog.naver.com/kylini/222051018321
#
# ▶ kylini
#
# 보기 좋은 떡이 먹기도 좋다!
# 라는 말이 있듯이
# 색색별로 다양한 쌀을 이용해서
# 맛있는 식사를 만들어보고 싶네요~
#
# 3일 동안 요리한 내용 담아서
# 꼼꼼한 후기와 동영상 남기겠습니다~ || 응모완료 ||  || https://blog.naver.com/tlstprp1979/222051708890
# https://cafe.naver.com/15668981/4129902
#
# 네이버 아이디 : tlstprp1979
# 인스타 아이디 : gimjungsun753
#
# 신청이유
#
# 쌀을 신청합니다.
# 제가 좋아하는 쌀이라서 신청합니다.
# 맛있는 리뷰를 올리겠습니다.
# 정성스러운 후기를 올리겠습니다. || 응모완료 || https://m.blog.naver.com/rhkdlfcjfja/222051782193
#
# https://l.facebook.com/l.php?u=https%3A%2F%2Fcafe.naver.com%2Fmiznett%2F2328690&h=AT1nhRQkzUxtnQTRGvVWwbz_f1KVOCbuBRoCsrhI2yRC3M6alflQYnVz5iMMlOZ9qEuCChm44FD9Q30xUB651YJXQpfORrSTWs4CZrfYuRHdv3bZ0M9hHrVfY7zjClU&s=1
# 네이버 아이디 rhkdlfcjfja
# 인스타 아이디 jieun7106
#
# 아기가 밥을 잘 안먹는 편이라 이것 저것 시도해 보고 있어요~!~!조금 먹더라고 영양 있는 밥을 주고 싶어서 신청합니다!!!꼭 선정되서 리얼 후기 남길께용~~!! || 스토어찜 소식받기 응모완료 || https://m.blog.naver.com/youbukim/222052105419
# https://story.kakao.com/_bCtPc3/GPXN9vnLDs0
#
# 네이버 youbukim
# 인스타 yunha_kimm
#
# 컬러쌀로 맛있는밥 해먹고 싶어요 ♡ || 응모완료 || https://m.blog.naver.com/hugyours/222052188481
# https://cafe.naver.com/happymmm/1194419
#
#
# hugyours 네이버
# loveinuso 인스타
#
# 홍국쌀 클로렐라쌀
#
# 어쩜 넘 이쁘네요
# 그냥 보기만해도 배부를듯요
# 건강에도 좋고 아이들도 잘 먹을듯하여 꼭 체험해보고픈 쌀이에용 || 응모완료 || https://www.facebook.com/100001638853463/posts/3507017526029508/?d=n
#
# https://m.blog.naver.com/hansoullove/222052213557
#
#
# 🌳 네이버 : hansoullove
# 🌳인스타 : baby__L.ha
#
# 완료.!
# 쌀이 이렇게 이뻐도 되나요~
# 밥잘 안먹는 아기 엄마예요, 이렇게 이쁘게 밥해주면 잘 먹을거 같아요 ~. 밥이 찰지고 맛있어 보이네요 건강까지 한번에 .!!!
#
# 꼭 이용해보고 후기 남겨보고 싶어요~~ ||  || 응모완료 || http://m.blog.naver.com/loveran3/222052370183
#
# https://story.kakao.com/_HBPEc6/fV7ZKT9WDs0
#
# 아이디 loveran3
#
# 컬러쌀이 색상별로 영양소도풍부하고 건강에좋은쌀이지요.
# 밥에넣어 알록달록 맛있고 예쁜밥먹어보고싶어요.
# 컬러밥으로 김밥싸면 정말예쁠것같아서 신청해봅니다
# 만약쌀이오면김밥부터 싸보고싶어요~^^ ||  || 응모완료 || http://m.blog.naver.com/ub9672/222050662067
#
# https://m.facebook.com/story.php?story_fbid=389620012016439&id=100029053304454
#
# 네이버 아이디 ub9672
# 인스타그램 mimi__1335
#
# 컬러쌀 아직 먹어본적이 없는데 형형색색 안록달록한게 너무 이쁘네요😊
# 눈으로도 즐겁고 입으로도 즐거우며 몸에도 좋은 하나로라이스 컬러쌀로 온가족 식탁을 꽃피워보고싶어 신청해봅니다.
#
# 선정해주시면 동영상 움짤 첨부해서 미러리스 카메라로 선명한 사진과 꼼꼼 리뷰로 보답드릴게요! ||  || 응모완료 || https://m.blog.naver.com/kimsoroung/222052633893
# https://cafe.naver.com/revieweverything/28712
#
# 네이버 ID: kimsoroung
# 인스타 ID: kimsoroung
#
# 다양한 색과 더불어 영양 듬뿍 영양쌀이네요. 먹어보고 싶어 신청합니다 후기가드라인애 맞게 쌀로 요리해서 맛있는 후기 남기겠습니다 || 응모완료 || https://m.blog.naver.com/tkxkd6501/222052686345
#
# https://cafe.naver.com/15668981/4130278
#
# 네이버아이디:tkxkd6501
# 인스타:y_min1747
#
# 컬러쌀 너무 예뻐요^^
# 건강에도 넘 좋다니 맛있고 예쁘게 체험해보고 싶어요!!
# 가족들과 예쁜밥 해서 후기남길께요!!
# 체험신청해봅니다!! || 찜완료 ||  || 응모완료 || https://m.blog.naver.com/nabiya277/222052712718
# https://cafe.naver.com/yebimom/280228
#
# 네이버아이디 nabiya277
#
#
# 건강에도좋은데 색김까지 더해지니
# 밥시간이 너무행복할꺼같아요
# 맛있게 지어서 다양하게 활용하는 리뷰남길게요 || 응모완료 || https://blog.naver.com/nglasshan/222053174553
# https://cafe.naver.com/playtomato/956459
#
# + 네이버 nglasshan
# + 인스타 twokids2017
# + 소식받기 완료, 스토어 찜완료
#
#
# 강황쌀 + 버섯쌀 택
#
# 어머나, 이런 신기함이~
# 정말로 이젠 쌀도 그냥 쌀이 아니군요~
# 꼭 만나보고 맛보고 싶어요 ^^ 신청합니다 || 응모완료 || https://cute1006.blog.me/222050965851
# https://cafe.naver.com/momsbloger/1124307
#
# 네이버 cute1006
# 인스타 cutebank1006
#
# 소식받기 완료, 스토어찜 완료
#
# 루테인+버섯쌀
#
# 보기에도 좋을뿐더러 건강에도 좋아 밥 먹을때마다 즐거울것 같아요
# 밥 많이 먹는 저희 집에 딱입니다
# 삼시세끼 밥은 꼭 먹어야하는 저희 가족에게 먹이고 싶습니다
# 정성후기도 약속드려요~ ||  || 응모완료 || https://blog.naver.com/nsyncbye1004/222053407259
# https://www.facebook.com/nsyncbyebye/posts/3719593258055494
# 네이버ID:nsyncbye1004
# 강황쌀,버섯쌀
# 너무 예쁜밥이 밥안먹는 아이들에게 너무 좋을꺼 같애요
# 김밥을 싸도 예쁘고 복음밥을 해도 너무 예쁠거 같습니다
# 꼼꼼후기 남길께요 || 응모완료 || https://m.blog.naver.com/littehyo/222053646492
# https://cafe.naver.com/dream0621/717660
#
# 네이버 littehyo
# 인스타 hyosoon194
#
# 홍국쌀+클로렐라쌀 희망해요
#
# 밥 잘안먹는 딸이기에 이쁜색이 입혀진 밥은 더잘먹을듯 싶어요
# 이쁜색뿐만 아니라 영양까지 첨부되어 있다고 하니 더욱 좋을듯 싶네요
# 특품종으로 쌀도 너무 좋을듯 싶어요
# 밥을 지었을때 이미지 영상 첨부해서 성실후기 남길게요
# 특히 색깔있는 밥을 좋아하며 맛나게 먹는 딸 모습도요 ||  || 응모완료 || ' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn("Ignoring URL '%s' with link or location/anchor > %d "
